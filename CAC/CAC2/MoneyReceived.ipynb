# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/suraj/Desktop/testing copy/cat.ipynb Cell 1 line 8
#       <a href='vscode-notebook-cell:/Users/suraj/Desktop/testing%20copy/cat.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> # Load data from CSV file
#       <a href='vscode-notebook-cell:/Users/suraj/Desktop/testing%20copy/cat.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> data = pd.read_csv('StudentData.csv')
# ----> <a href='vscode-notebook-cell:/Users/suraj/Desktop/testing%20copy/cat.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> g = sns.catplot(x="Have you paid fine in Christ? ",
#       <a href='vscode-notebook-cell:/Users/suraj/Desktop/testing%20copy/cat.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a>                 y="Select Your Branch.",
#      <a href='vscode-notebook-cell:/Users/suraj/Desktop/testing%20copy/cat.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>                 hue="Have you paid fine in Christ? ",
# ...
