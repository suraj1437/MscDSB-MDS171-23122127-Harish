# %%
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("StudentData.csv")
df
import pandas as pd
import matplotlib.pyplot as plt

# Load data from CSV file
data = pd.read_csv('StudentData.csv')

# Group by branch and Fine Paid and count number of responses
Fine_Count = data.groupby(['Select Your Branch.', 'Have you paid fine in Christ? ']).size().reset_index(name='count')
print(Fine_Count)
# Pivot table and create stacked bar chart
Fine_Count = Fine_Count.pivot(index='Select Your Branch.', columns='Have you paid fine in Christ? ', values='count')
Fine_Count.plot(kind='bar', stacked=True)
plt.title('Fine Count')
plt.xlabel('Branch')
plt.ylabel('Number of Responses')
plt.legend(title='Fine Amount', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
#                Timestamp Select Your Branch.  \
# 0        8/10/2023 17:16        Data Science
# 1        8/10/2023 17:17        Data Science
# 2        8/10/2023 17:18        Data Science
# 3        8/10/2023 17:28              BA LLB
# 4        8/10/2023 17:30              BA LLB
# ..                   ...                 ...
# 297  10/20/2023 18:54:01                 MBA
# 298  10/20/2023 18:54:22        Data Science
# 299  10/20/2023 18:54:43                 MBA
# 300  10/20/2023 18:55:04                 MBA
# 301  10/21/2023 15:10:59        Data Science
#
#      How much money you get for monthly expenses from family?  \
# 0                                                 8000
# 1                                                 5000
# 2                                                10000
# 3                                                10000
# 4                                                10000
# ..                                                 ...
# ...
